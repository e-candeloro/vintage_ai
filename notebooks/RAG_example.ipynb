# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data  vintage_ai

# %%
# !git clone https://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@github.com/e-candeloro/vintage_ai.git

# %%
# %cd drive/MyDrive/Colab Notebooks/vintage_ai
# Out:
# /content/drive/MyDrive/Colab Notebooks/vintage_ai

# %%
# !git checkout -b michelle_branch
# Out:
# fatal: A branch named 'michelle_branch' already exists.

# %%
# !git status
# Out:
# Refresh index: 100% (13/13), done.
# On branch michelle_branch
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	notebooks/web_scraper
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !pip install uv
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)
# Requirement already satisfied: uv in /usr/local/lib/python3.11/dist-packages (0.7.11)
# WARNING: Ignoring invalid distribution ~vidia-cufft-cu12 (/usr/local/lib/python3.11/dist-packages)

# %%
# !ls
# Out:
# documents  notebooks  pyproject.toml  README.md  src  uv.lock

# %%
# !git add notebooks/RAG_example.ipynb
# !git commit -m "Add RAG"
# !git push origin michelle_branch

# %%
# packages for RAG

# !pip install -q torch transformers accelerate bitsandbytes langchain sentence-transformers faiss-cpu openpyxl pacmap datasets ragatouille
# !pip install langchain_community
# !pip install -U bitsandbytes
# !pip install pacmap
# !pip install langchain_huggingface
# !pip install langgraph

# %%
import getpass
import os
from langchain.chat_models import init_chat_model

# SET THE ENVIRNMONENTS for TRAKING on LANGSMITH

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "RAG_example"
print(os.environ.get("LANGSMITH_PROJECT"))

if "LANGSMITH_API_KEY" not in os.environ:
    os.environ["LANGSMITH_API_KEY"] = "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"
# Out:
# RAG_example

# %% [markdown]
# # INIZIALIZZAZIONE DI TUTTI GLI STEP CHE MI SERVONO:
#   - LLM usato
#   - Embedding model per i documenti
#   - Database vettoriale con ricerca FAISS di similarità

# %% [markdown]
# ## LLm

# %%
# INIT THE LLM MODEL using hugging face
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from langchain.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate
from transformers import pipeline
from langchain_core.output_parsers import StrOutputParser

model_name = "HuggingFaceH4/zephyr-7b-beta"

# to be more fast
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, bnb_4bit_use_double_quant=True, bnb_4bit_quant_type="nf4", bnb_4bit_compute_dtype=torch.bfloat16
)

model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=bnb_config)
tokenizer = AutoTokenizer.from_pretrained(model_name)

text_generation_pipeline = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    temperature=0.2,
    do_sample=True,
    repetition_penalty=1.1,
    return_full_text=True,
    max_new_tokens=400,
)

llm = HuggingFacePipeline(pipeline=text_generation_pipeline)
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# Device set to use cuda:0
# <ipython-input-13-597b175229d9>:30: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# %% [markdown]
# ## Template del prompt modificabile

# %%
# prompt that can be changed on the basis of the task

prompt_template = """
<|system|>
Answer the question based on your knowledge. Use the following context to help:

{context}

</s>
<|user|>
{question}
</s>
<|assistant|>

 """

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template,
)

print(prompt)
# Out:
# input_variables=['context', 'question'] input_types={} partial_variables={} template='\n<|system|>\nAnswer the question based on your knowledge. Use the following context to help:\n\n{context}\n\n</s>\n<|user|>\n{question}\n</s>\n<|assistant|>\n\n '

# %% [markdown]
# ## Embeddings

# %%
# INIT EMBEDDING MODEL
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## VECTOR DB

# %%
# INIT VECTOR STORE, I chose to use FAISS

import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain import hub
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langgraph.graph import START, StateGraph
from typing_extensions import List, TypedDict
import re
from bs4 import BeautifulSoup
import bs4
from langchain_community.document_loaders import RecursiveUrlLoader

def bs4_extractor(html: str) -> str:
    soup = BeautifulSoup(html, "lxml",
                        parse_only=bs4.SoupStrainer(class_ = ("discussionListItems")))

    return re.sub(r"\n\n+", "\n\n", soup.text).strip()

loader = RecursiveUrlLoader(
    "https://www.ferrarichat.com/forum/forums/cars.303/",
    max_depth = 1,
    prevent_outside=True,
    extractor=bs4_extractor,
)
print(loader.load()[0].page_content[:1000])
# Out:
# For Sale
# Attn Collectors!  The finest, most original and most expensive Testarossa anywhere.
#
# AMG USA,
#
# Mar 3, 2025 at 1:54 PM
#
# Replies: 16
# Views: 4,703
#
# Motob
#
# Jun 4, 2025 at 8:49 PM
#
# For Sale
# 1998 Ferrari 355 Spider F1 Blue Nart/Cuoio **Rare Spec**Fully Serviced**
#
# Scuderia 110,
#
# May 8, 2025 at 6:18 PM
#
# Replies: 2
# Views: 1,171
#
# Scuderia 110
#
# Jun 4, 2025 at 6:58 PM
#
# For Sale
# 2008 FERRARI 430 SPIDER NERO/NERO **FULLY SERVICED**
#
# Scuderia 110,
#
# May 7, 2025 at 9:25 AM
#
# Replies: 5
# Views: 1,714
#
# Scuderia 110
#
# Jun 2, 2025 at 3:50 PM
#
# Auction
# 1995 Ferrari F512 M w/ Carbon Buckets
#
# GLENN@TEAM AI,
#
# May 29, 2025 at 9:08 PM
#
# Replies: 3
# Views: 658
#
# tx246
#
# May 31, 2025 at 4:07 PM
#
# Wanted
# LaFerrari
#
# Woodhouse Select,
#
# May 13, 2019 at 1:28 PM
#
# Replies: 10
# Views: 4,798
#
# Grigioingrid12
#
# May 31, 2025 at 2:52 PM
#
# Sale Pending
# 2002 Ferrari 360 6 Speed Manual
#
# calder1,
#
# Oct 15, 2024 at 5:23 PM
#
# ...
# 2
#
# Replies: 37
# Views: 11,552
#
# beemerb0y
#
# May 30, 2025 at 11:10 PM
#
# For Sale
# 20

# %%
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
all_splits = text_splitter.split_documents(docs)

vector_store = FAISS.from_documents(all_splits, embeddings)

# %% [markdown]
# # LANGCHAIN GRAPH: per tenere traccia di tutta la pipeline
#  - Retrieve: Similarity search
#  - Generate: Chiamata all'LLM con documenti trovati nel vector db e domanda
#  - Effettiva chiamata alla pipeline

# %%
# Define state for application
class State(TypedDict):
    question: str
    context: List[Document]
    answer: str


# Define application steps
def retrieve(state: State):
    retrieved_docs = vector_store.similarity_search(state["question"])
    return {"context": retrieved_docs}


def generate(state: State):
    docs_content = "\n\n".join(doc.page_content for doc in state["context"])
    messages = prompt.invoke({"question": state["question"], "context": docs_content})
    response = llm.invoke(messages)
    return {"answer": response}


# Compile application and test
graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()

# %%
response = graph.invoke({"question": "What are the most popular themes in the classic car comunity in the last days?"})
print(response["answer"])
# Out:
# <|system|>
# Answer the question based on your knowledge. Use the following context to help:
#
# AMG USA,
#
# Apr 21, 2025 at 3:31 PM
#
# Replies: 6
# Views: 1,649
#
# bertrand328
#
# Apr 22, 2025 at 2:14 PM
#
# For Sale
# YC SUPERCARS LAUNCHES A NEW CONSULTING SERVICE FOR BUYERS!!
#
# Yellow Compass,
#
# Aug 30, 2023 at 10:25 PM
#
# ...
# 2
# 3
# 4
#
# Replies: 84
# Views: 23,182
#
# Yellow Compass
#
# Apr 22, 2025 at 12:56 PM
#
# Sold
# ICE ICE BABY!! LIKE VANILLA-2011 458 COUPE WHITE/TAN 10,000 miles!!
#
# Yellow Compass,
#
# Feb 9, 2025 at 2:32 PM
#
# Replies: 12
# Views: 4,583
#
# Yellow Compass
#
# Apr 19, 2025 at 8:47 AM
#
# For Sale
# 1998 Ferrari F355 - 6 speed manual + Canna Di Fucile
#
# SnackGuy,
#
# Oct 8, 2024 at 11:41 AM
#
# Replies: 8
# Views: 5,664
#
# Joshman0531
#
# Apr 18, 2025 at 7:48 PM
#
# Taken Off Market
# 2013 458 SPIDER WHITE/BlACK 22,777 mi.
#
# Yellow Compass,
#
# Feb 11, 2025 at 11:23 PM
#
# Replies: 10
# Views: 4,096
#
# Yellow Compass
#
# Apr 17, 2025 at 5:24 PM
#
# For Sale
# 1989 Ferrari Testarossa - White/Tan, Cavallino Platinum
#
# GLENN@TEAM AI,
#
# Apr 15, 2025 at 7:52 AM
#
# Replies: 6
# Views: 1,732
#
# GLENN@TEAM AI
#
# Feb 10, 2025 at 11:19 AM
#
# For Sale
# 1983 Ferrari 308 GTS QV Argento/Nero 30K Miles
#
# Scuderia 110,
#
# Nov 25, 2024 at 4:15 PM
#
# Replies: 6
# Views: 3,665
#
# Scuderia 110
#
# Feb 2, 2025 at 1:02 PM
#
# Sold
# 2019 Ferrari Portofino Rosso Corsa/Tortora Only 5K Miles
#
# Scuderia 110,
#
# Sep 10, 2024 at 5:57 PM
#
# Replies: 12
# Views: 5,215
#
# Scuderia 110
#
# Jan 28, 2025 at 12:39 PM
#
# Taken Off Market
# 1931 BUGATTI TYPE 51 BY PUR SANG
#
# Yellow Compass,
#
# Aug 30, 2024 at 11:28 AM
#
# ...
# 2
#
# Replies: 34
# Views: 8,118
#
# Yellow Compass
#
# Jan 26, 2025 at 11:07 PM
#
# Sold
# RARE!! 2000 360 COUPE STICK!! ONE OWNER! RED/BLACK 9200 mi. MINT!!
#
# Yellow Compass,
#
# Jan 20, 2025 at 8:34 PM
#
# Replies: 12
# Views: 2,855
#
# FerrfanFL
#
# Jan 23, 2025 at 11:11 AM
#
# Replies: 10
# Views: 6,804
#
# triblk6spd
#
# Feb 12, 2025 at 10:09 PM
#
# Taken Off Market
# 2FAS4U!! 2023 296 GTB GRIGIO SCURO/RED 900 mi MINT!!
#
# Yellow Compass,
#
# Jan 6, 2025 at 5:57 PM
#
# Replies: 12
# Views: 3,781
#
# Yellow Compass
#
# Feb 12, 2025 at 1:30 PM
#
# Taken Off Market
# SUPER BOWL SPECIAl!! 2013 458 SPIDER-BLACK/TAN 14,000 miles MINT!!!!
#
# Yellow Compass,
#
# Feb 9, 2025 at 10:00 AM
#
# Replies: 1
# Views: 1,662
#
# Yellow Compass
#
# Feb 12, 2025 at 11:39 AM
#
# Sold
# VROOM!! 2020 812 SUPERFAST GRIGIO FERRO/BLACK LEATHER-ALCANTARA 11,700 mi
#
# Yellow Compass,
#
# Feb 8, 2025 at 6:55 PM
#
# Replies: 2
# Views: 1,766
#
# Yellow Compass
#
# Feb 10, 2025 at 6:25 PM
#
# Taken Off Market
# 2024 BMW-XM 500 miles!!
#
# Yellow Compass,
#
# Feb 7, 2025 at 1:41 PM
#
# Replies: 10
# Views: 1,871
#
# Yellow Compass
#
# Feb 10, 2025 at 11:19 AM
#
# For Sale
# 1983 Ferrari 308 GTS QV Argento/Nero 30K Miles
#
# Scuderia 110,
#
# Nov 25, 2024 at 4:15 PM
#
# Replies: 6
# Views: 3,665
#
# Scuderia 110
#
# Feb 2, 2025 at 1:02 PM
#
# Scuderia 110,
#
# Nov 4, 2023 at 2:41 AM
#
# ...
# 2
#
# Replies: 28
# Views: 14,165
#
# spike308
#
# May 19, 2025 at 8:52 PM
#
# For Sale
# 1973 Landrover series 3
#
# calder1,
#
# Apr 7, 2025 at 4:42 PM
#
# Replies: 10
# Views: 2,038
#
# It's Ed
#
# May 11, 2025 at 10:14 AM
#
# Wanted
# 458 SPIDERS AND COUPES ALL COLORS
#
# Yellow Compass,
#
# Jan 13, 2025 at 10:34 AM
#
# Replies: 4
# Views: 2,380
#
# Yellow Compass
#
# May 8, 2025 at 1:40 PM
#
# Sold
# 2005 Ferrari 430 Spider F1 Blu Pozzi w/ 12K Miles **Fresh Service**
#
# Scuderia 110,
#
# Apr 15, 2025 at 1:07 PM
#
# Replies: 5
# Views: 2,044
#
# rhs72
#
# May 1, 2025 at 12:16 AM
#
# Sold
# WE LOVE VANILLA!! 2015 F12 BIANCO AVUS/BLACK 9700 mi MINT!!
#
# Yellow Compass,
#
# Apr 22, 2025 at 9:27 PM
#
# Replies: 1
# Views: 1,606
#
# Yellow Compass
#
# Apr 27, 2025 at 7:27 PM
#
# For Sale
# 1989 Ferrari 328 GTB with 7187 miles
#
# AMG USA,
#
# Apr 21, 2025 at 3:31 PM
#
# Replies: 6
# Views: 1,649
#
# bertrand328
#
# Apr 22, 2025 at 2:14 PM
#
# For Sale
# YC SUPERCARS LAUNCHES A NEW CONSULTING SERVICE FOR BUYERS!!
#
# </s>
# <|user|>
# What are the most popular themes in the classic car comunity in the last days?
# </s>
# <|assistant|>
#
#   Based on recent activity and discussions within the classic car community, some of the most popular themes in the last few days include:
#
# 1. Restoration projects: Many classic car enthusiasts are currently working on restoring their vehicles to their former glory. This can range from simple cosmetic updates to full-blown engine rebuilds and bodywork repairs.
#
# 2. Vintage racing events: Classic cars were designed to be driven, and many owners participate in vintage racing events as a way to showcase their vehicles and compete against other like-minded individuals.
#
# 3. Preservation vs. Restoration debates: There is ongoing discussion about whether it's better to preserve a classic car in its original condition or restore it to improve performance and reliability. Some argue that preservation is more important for historical accuracy, while others believe that restoration is necessary to keep the vehicle running smoothly.
#
# 4. Rare and unique finds: Members of the classic car community are always on the lookout for rare and unique vehicles that stand out from the crowd. These could be one-of-a-kind prototypes, limited edition models, or simply cars that have been well-maintained over the years.
#
# 5. Maintenance tips and advice: As classic cars age, they require special care and attention to ensure they continue to run smoothly. Community members share tips and advice on how to maintain these vehicles, including regular oil changes, tire rotations, and brake inspections.
#
# 6. Classic car shows and exhibitions: Many classic car enthusiasts attend shows and exhibitions to admire the vehicles on display and learn more about the history and technology behind them. These events also provide opportunities to network with other collectors and potential buyers.
#
# 7. Classic car auctions: Auction houses often hold sales featuring classic cars, providing an opportunity for collectors to acquire rare and valuable vehicles. These events also generate significant media

# %%
# !git config --global user.email "paganimichelle0499@gmail.com"
# !git config --global user.name "michelle2399"

# %%
# !git add notebooks/RAG_example.ipynb
# !git commit -m "Add RAG riprova"
# !git push origin michelle_branch
# Out:
# On branch michelle_branch
# nothing to commit, working tree clean
# Everything up-to-date
